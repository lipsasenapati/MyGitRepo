# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/lipsasenapati/MyGitRepo/blob/master/init.ipynb)

# %%
 import requests
from bs4 import BeautifulSoup



headers = {'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/53.0.2785.143 Safari/537.36'}
# Collect and parse first page
page = requests.get('https://www.apartments.com/richardson-tx/',headers=headers, timeout=5)
soup = BeautifulSoup(page.text, 'html.parser')

if page.status_code == 200:
    print('The request is 200')
else:
    print('The request is not 200')

print (soup)
# Out:
# The request is 200
#
# <!DOCTYPE html>
#
# <html data-placeholder-focus="false" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="email=no" name="format-detection"/>
# <meta content="true" name="HandheldFriendly"/>
# <title> Apartments for Rent in Richardson TX | Apartments.com</title>
# <link href="/a/8a55f9/favicon.ico" rel="icon"/>
# <link href="https://www.apartments.com/richardson-tx/" rel="canonical">
# <meta content="Richardson apartments for rent, condos, townhomes, houses for rent" name="keywords"/>
# <link href="https://plus.google.com/+apartmentscom/" rel="publisher"/>
# <meta content="See all 3,307 apartments in Richardson, TX currently available for rent. Each Apartments.com listing has verified availability, rental rates, photos, floor plans and more." name="description"/>
# ...
